# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')
df
# Out:
#                                     CLMU_contribution  \
# 0                        Air temperature UHI analysis
# 1                         Biophysical analysis of UHI
# 2                           Urban humid heat modeling
# 3             Urban temperature and humidity modeling
# 4   Urban canopy air temperature and anthropogenic...
# 5                         UHI and heat index modeling
# 6      Urban heat island and thermal comfort modeling
# 7                               Urban runoff modeling
# 8                          Urban temperature modeling
# 9             Urban temperature and humidity modeling
# 10                         Urban heat island analysis
# 11                    Validate white roofs adaptation
#
#                                                 Theme  \
# 0               Spatial patterns and mechanism of UHI
# 1                                    Mechanism of UHI
# 2                              Mechanism of humid hea
# ...

# %%
rname = {'CLMU_contribution':'CLMU contribution', 'First_country':'Countries', 'Bib':'Ref'}
df_table = df[['Theme','CLMU_contribution','Year', 'First_country','Bib']].rename(columns=rname)
df_table
# Out:
#                                                 Theme  \
# 0               Spatial patterns and mechanism of UHI
# 1                                    Mechanism of UHI
# 2                              Mechanism of humid hea
# 3             Projection of humid heat and adaptation
# 4   Spatial and temporal patterns of urban canopy ...
# 5   Correlated analysis of UHI/heat index  and cli...
# 6   Modeling  of UHI and thermal comfort during he...
# 7   Analysis of climate change on global total and...
# 8                      Projection of urban heat wave
# 9       Projection of urban temperature and  humidity
# 10                                   Mechanism of UHI
# 11                              Valiation of adpation
#
#                                     CLMU contribution  Year  \
# 0                        Air temperature UHI analysis  2024
# 1                         Biophysical analysis of UHI  2024
# 2                           Urban humid heat modeling  2023
# ...

# %%
latex_table = df_table.to_latex(index=False)
print(latex_table)
# Out:
# \begin{tabular}{llrll}
# \toprule
#                                              Theme &                                  CLMU contribution &  Year &         Countries &                                                Ref \\
# \midrule
#              Spatial patterns and mechanism of UHI &                       Air temperature UHI analysis &  2024 &             China &                     \textbackslash cite\{LYUETAL24Adv.Atmos.Sci.\} \\
#                                   Mechanism of UHI &                        Biophysical analysis of UHI &  2024 &             China &           \textbackslash cite\{LIETAL24J.Geophys.Res.Atmospheres\} \\
#                             Mechanism of humid hea &                          Urban humid heat modeling &  2023 &               USA &                          \textbackslash cite\{ZHANGETAL23Natureb\} \\
# ...
